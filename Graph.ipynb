# %% [raw]
# %jekyll
# layout:     post
# title:      Academic Geneology
# description: Using pyGraphViz to plot my academic Tree
# categories: geneology python ucsd

# %% [markdown]
# ## Academic Tree Graph

# %% [markdown]
# A few years ago I saw a nice presentation of a friend's academic geneology (his advisor, and so forth).
# I quickly scraped wikipedia for most of my tree, but never ended up making it presentable.
# More recently Darcy showed me hers, so I finally got around to making a nice graph representation of the some of the UCSD professors that I could scrape from wikipedia and random websites.
#
# Here is a pretty simple directed graph of the lineage.
# After adding both Brian, Kim, and George I half expected that the the full academic tree space was much smaller than it really is.
# By no means do I think this is a complete graph of these professors, and is merely what I could do in the last hour or two.
# If you find any problems or issues let me know, or submit a pull request to the [github](https://github.com/ajmendez/AcademicGenealogy).
#
# A larger image can be found [here](https://github.com/ajmendez/AcademicGenealogy/2014_tree.png).

# %%
from graph import makegraph
from IPython.core.display import Image

# %%
G = makegraph()
G.layout(prog='dot')
img = G.draw(format='png')
Image(img)
